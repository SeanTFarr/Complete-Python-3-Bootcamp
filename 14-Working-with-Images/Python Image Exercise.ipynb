# %%
from PIL import Image

# %%
matrix = Image.open('word_matrix.png')

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x189740DC280>

# %%
matrix.size
# Out:
# (1015, 559)

# %%
matrix.putalpha(128)

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x189740DC280>

# %%
mask = Image.open('mask.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x189742A5BE0>

# %%
mask.size
# Out:
# (505, 251)

# %%
mask.putalpha(128)

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x189742A5BE0>

# %%
full_mask = mask.resize((1015, 559))

# %%
matrix.paste(full_mask,box=(0,0),mask=full_mask)

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x189740DC280>
